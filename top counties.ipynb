# %%
import pandas as pd

# %%
counties = pd.read_csv('Resource/top100counties.csv')

# %%
counties
# Out:
#     Rank                Geographic Area Population Estimate Unnamed: 3  \
# 0      1  Williams County, North Dakota              22,399     37,589
# 1      2             Hays County, Texas             157,103    230,191
# 2      3           Wasatch County, Utah              23,525     34,091
# 3      4            Comal County, Texas             108,520    156,209
# 4      5          Kendall County, Texas              33,384     47,431
# ..   ...                            ...                 ...        ...
# 95    96      Limestone County, Alabama              82,786     98,915
# 96    97            Teton County, Idaho              10,165     12,142
# 97    98    Falls Church city, Virginia              12,244     14,617
# 98    99          Pasco County, Florida             464,705    553,947
# 99   100   Union County, North Carolina             201,332    239,859
#
#    Change, 2010 to 2019  Unnamed: 5
# 0                15,190        67.8
# 1                73,088        46.5
# ...

# %%
counties_chosen=counties[counties['Geographic Area'].str.contains('Texas|Utah|Colorado|Florida|Nevada|Idaho|Arizona|North Dakota|Washington|District of Columbia')]

# %%
counties_chosen=counties_chosen.rename(columns={'Unnamed: 3':'population estimate 2019','Unnamed: 5' : 'Percent Change'})
counties_chosen
# Out:
#     Rank                Geographic Area Population Estimate  \
# 0      1  Williams County, North Dakota              22,399
# 1      2             Hays County, Texas             157,103
# 2      3           Wasatch County, Utah              23,525
# 3      4            Comal County, Texas             108,520
# 4      5          Kendall County, Texas              33,384
# 5      6         Sumter County, Florida              93,420
# 7      8        Osceola County, Florida             268,685
# 8      9       Williamson County, Texas             422,504
# 9     10      St. Johns County, Florida             190,038
# 11    12        Fort Bend County, Texas             584,699
# 14    15         Walton County, Florida              55,046
# 15    16         Rockwall County, Texas              78,345
# 16    17           Denton County, Texas             662,557
# 17    18       Montgomery County, Texas             455,747
# 19    20           Collin County, Texas             781,419
# ...

# %% [markdown]
# Table formatted from table listing of top 100 counties with largest percent change

# %%
dc = pd.read_csv('Resource/dc_popchange.csv')

# %%
dc
# Out:
#              Unnamed: 0 April 1, 2010 Estimates Base 1-Jul-19   Change  \
# 0  District of Columbia                      601,767  705,749  103,982
#
#    Percent
# 0     17.3

# %%
states = ['Texas','Utah','Colorado','Florida','Nevada','Idaho','Arizona','North Dakota','Washington']

for state in states:
    top_counties = counties_chosen[counties_chosen['Geographic Area'].str.contains(state)]
    if state == 'Texas':
        toptex = pd.DataFrame(top_counties)
    elif state == 'Utah':
        toputah = pd.DataFrame(top_counties)
    elif state == 'Colorado':
        topcol = pd.DataFrame(top_counties)
    elif state == 'Florida':
        topflor = pd.DataFrame(top_counties)
    elif state == 'Nevada':
        topnev = pd.DataFrame(top_counties)
    elif state == 'Idaho':
        topida = pd.DataFrame(top_counties)
    elif state == 'Arizona':
        toparz = pd.DataFrame(top_counties)  
    elif state == 'North Dakota':
        topndk = pd.DataFrame(top_counties)
    elif state == 'Washington':
        topwa = pd.DataFrame(top_counties)

# %%
toptex
# Out:
#     Rank           Geographic Area Population Estimate  \
# 1      2        Hays County, Texas             157,103
# 3      4       Comal County, Texas             108,520
# 4      5     Kendall County, Texas              33,384
# 8      9  Williamson County, Texas             422,504
# 11    12   Fort Bend County, Texas             584,699
# 15    16    Rockwall County, Texas              78,345
# 16    17      Denton County, Texas             662,557
# 17    18  Montgomery County, Texas             455,747
# 19    20      Collin County, Texas             781,419
# 21    22     Kaufman County, Texas             103,348
# 27    28     Midland County, Texas             136,872
# 34    35      Waller County, Texas              43,274
# 35    36   Guadalupe County, Texas             131,527
# 38    39     Andrews County, Texas              14,786
# 45    46    Chambers County, Texas              35,107
# 47    48      Travis County, Texas           1,024,444
# ...

# %%
toputah
# Out:
#     Rank          Geographic Area Population Estimate  \
# 2      3     Wasatch County, Utah              23,525
# 28    29  Washington County, Utah             138,115
# 49    50      Tooele County, Utah              58,218
# 55    56        Utah County, Utah             516,639
#
#    population estimate 2019 Change, 2010 to 2019  Percent Change
# 2                    34,091               10,566            44.9
# 28                  177,556               39,441            28.6
# 49                   72,259               14,041            24.1
# 55                  636,235              119,596            23.1

# %%
topcol
# Out:
#     Rank              Geographic Area Population Estimate  \
# 29    30        Weld County, Colorado             252,827
# 40    41  Broomfield County, Colorado              55,861
# 58    59     Douglas County, Colorado             285,465
# 74    75      Denver County, Colorado             599,825
#
#    population estimate 2019 Change, 2010 to 2019  Percent Change
# 29                  324,492               71,665            28.3
# 40                   70,465               14,604            26.1
# 58                  351,154               65,689            23.0
# 74                  727,211              127,386            21.2

# %%
topflor
# Out:
#     Rank               Geographic Area Population Estimate  \
# 5      6        Sumter County, Florida              93,420
# 7      8       Osceola County, Florida             268,685
# 9     10     St. Johns County, Florida             190,038
# 14    15        Walton County, Florida              55,046
# 44    45       Manatee County, Florida             322,879
# 46    47           Lee County, Florida             618,755
# 51    52          Lake County, Florida             297,047
# 66    67    Santa Rosa County, Florida             151,371
# 69    70        Orange County, Florida           1,145,957
# 77    78        Nassau County, Florida              73,310
# 83    84          Polk County, Florida             602,073
# 84    85       Flagler County, Florida              95,692
# 89    90  Hillsborough County, Florida           1,229,202
# 90    91       Collier County, Florida             321,522
# 98    99         Pasco County, Florida             464,705
#
# ...

# %%
topnev
# Out:
# Empty DataFrame
# Columns: [Rank, Geographic Area, Population Estimate, population estimate 2019, Change, 2010 to 2019, Percent Change]
# Index: []

# %%
topida
# Out:
#     Rank         Geographic Area Population Estimate population estimate 2019  \
# 59    60       Ada County, Idaho             392,372                  481,587
# 68    69    Canyon County, Idaho             188,922                  229,849
# 91    92  Kootenai County, Idaho             138,466                  165,697
# 96    97     Teton County, Idaho              10,165                   12,142
#
#    Change, 2010 to 2019  Percent Change
# 59               89,215            22.7
# 68               40,927            21.7
# 91               27,231            19.7
# 96                1,977            19.4

# %%
toparz
# Out:
#     Rank        Geographic Area Population Estimate population estimate 2019  \
# 54    55  Pinal County, Arizona             375,764                  462,789
#
#    Change, 2010 to 2019  Percent Change
# 54               87,025            23.2

# %%
 topndk
# Out:
#     Rank                Geographic Area Population Estimate  \
# 0      1  Williams County, North Dakota              22,399
# 25    26     Stark County, North Dakota              24,199
# 71    72      Cass County, North Dakota             149,778
#
#    population estimate 2019 Change, 2010 to 2019  Percent Change
# 0                    37,589               15,190            67.8
# 25                   31,489                7,290            30.1
# 71                  181,923               32,145            21.5

# %%
 topwa = topwa[1:2]

# %%
topwa
# Out:
#     Rank              Geographic Area Population Estimate  \
# 65    66  Franklin County, Washington              78,160
#
#    population estimate 2019 Change, 2010 to 2019  Percent Change
# 65                   95,222               17,062            21.8
